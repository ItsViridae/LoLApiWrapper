# %%
#PullLoLDataAssets
import requests
import json
# Get Current Patch
def getCurrentVersion():
    versionResponse = requests.get("https://ddragon.leagueoflegends.com/api/versions.json")
    version_patch_RawData = versionResponse.json()
    currentVersion = version_patch_RawData[0]
    print(currentVersion)
    return currentVersion

#champions, items, summoner_spells, spells
def GetDDragonData_Champions():
    version = getCurrentVersion()
    #Champions Data
    response = requests.get("http://ddragon.leagueoflegends.com/cdn/"+version+"/data/en_US/champion.json")
    allChampionRawData = json.loads(response.text)

    ChampionIdToName = {}
    for key,champion in allChampionRawData['data'].items():
        ChampionIdToName[int(champion['key'])] = champion['name']
    print(ChampionIdToName)
    return ChampionIdToName

def GetDDragonData_Items():
    version = getCurrentVersion()
    response = requests.get("http://ddragon.leagueoflegends.com/cdn/"+version+"/data/en_US/item.json")
    allItemsRawData = json.loads(response.text)
    QuickPrinter(allItemsRawData)

    #Items Data
    ItemIdToName = {}
    for key,item in allItemsRawData['data'].items():
        ItemIdToName[int(key)] = item['name']
    print(ItemToToName)
    return ItemIdToName

def QuickPrinter(String_to_Print):
    print(json.dumps(String_to_Print, indent=4, sort_keys=True))

#main()
version = getCurrentVersion()
GetDDragonData_Champions()
GetDDragonData_Items()
# Out:
# 10.12.1
# 10.12.1
# {266: 'Aatrox', 103: 'Ahri', 84: 'Akali', 12: 'Alistar', 32: 'Amumu', 34: 'Anivia', 1: 'Annie', 523: 'Aphelios', 22: 'Ashe', 136: 'Aurelion Sol', 268: 'Azir', 432: 'Bard', 53: 'Blitzcrank', 63: 'Brand', 201: 'Braum', 51: 'Caitlyn', 164: 'Camille', 69: 'Cassiopeia', 31: "Cho'Gath", 42: 'Corki', 122: 'Darius', 131: 'Diana', 119: 'Draven', 36: 'Dr. Mundo', 245: 'Ekko', 60: 'Elise', 28: 'Evelynn', 81: 'Ezreal', 9: 'Fiddlesticks', 114: 'Fiora', 105: 'Fizz', 3: 'Galio', 41: 'Gangplank', 86: 'Garen', 150: 'Gnar', 79: 'Gragas', 104: 'Graves', 120: 'Hecarim', 74: 'Heimerdinger', 420: 'Illaoi', 39: 'Irelia', 427: 'Ivern', 40: 'Janna', 59: 'Jarvan IV', 24: 'Jax', 126: 'Jayce', 202: 'Jhin', 222: 'Jinx', 145: "Kai'Sa", 429: 'Kalista', 43: 'Karma', 30: 'Karthus', 38: 'Kassadin', 55: 'Katarina', 10: 'Kayle', 141: 'Kayn', 85: 'Kennen', 121: "Kha'Zix", 203: 'Kindred', 240: 'Kled', 96: "Kog'Maw", 7: 'LeBlanc', 64: 'Lee Sin', 89: 'Leona', 127: 'Lissandra', 236: 'Lucian', 117: 'Lulu', 99: 'Lux', 54: 'Malphite', 90: 'Malzahar', 57: 'Maokai', 11: 'Master Yi', 21: 'Miss Fortune', 62: 'Wukong', 82: 'Mordekaiser', 25: 'Morgana', 267: 'Nami', 75: 'Nasus', 111: 'Nautilus', 518: 'Neeko', 76: 'Nidalee', 56: 'Nocturne', 20: 'Nunu & Willump', 2: 'Olaf', 61: 'Orianna', 516: 'Ornn', 80: 'Pantheon', 78: 'Poppy', 555: 'Pyke', 246: 'Qiyana', 133: 'Quinn', 497: 'Rakan', 33: 'Rammus', 421: "Rek'Sai", 58: 'Renekton', 107: 'Rengar', 92: 'Riven', 68: 'Rumble', 13: 'Ryze', 113: 'Sejuani', 235: 'Senna', 875: 'Sett', 35: 'Shaco', 98: 'Shen', 102: 'Shyvana', 27: 'Singed', 14: 'Sion', 15: 'Sivir', 72: 'Skarner', 37: 'Sona', 16: 'Soraka', 50: 'Swain', 517: 'Sylas', 134: 'Syndra', 223: 'Tahm Kench', 163: 'Taliyah', 91: 'Talon', 44: 'Taric', 17: 'Teemo', 412: 'Thresh', 18: 'Tristana', 48: 'Trundle', 23: 'Tryndamere', 4: 'Twisted Fate', 29: 'Twitch', 77: 'Udyr', 6: 'Urgot', 110: 'Varus', 67: 'Vayne', 45: 'Veigar', 161: "Vel'Koz", 254: 'Vi', 112: 'Viktor', 8: 'Vladimir', 106: 'Volibear', 19: 'Warwick', 498: 'Xayah', 101: 'Xerath', 5: 'Xin Zhao', 157: 'Yasuo', 83: 'Yorick', 350: 'Yuumi', 154: 'Zac', 238: 'Zed', 115: 'Ziggs', 26: 'Zilean', 142: 'Zoe', 143: 'Zyra'}
# 10.12.1
# {
#     "basic": {
#         "colloq": ";",
#         "consumeOnFull": false,
#         "consumed": false,
#         "depth": 1,
#         "description": "",
#         "from": [],
#         "gold": {
#             "base": 0,
#             "purchasable": false,
#             "sell": 0,
#             "total": 0
#         },
#         "group": "",
#         "hideFromAll": false,
#         "inStore": true,
#         "into": [],
#         "maps": {
#             "1": true,
#             "10": true,
#             "12": true,
#             "8": true
#         },
#         "name": "",
#         "plaintext": "",
#         "requiredAlly": "",
#         "requiredChampion": "",
#         "rune": {
#             "isrune": false,
#             "tier": 1,
#             "type": "red"
#         },
#         "specialRecipe": 0,
#         "stacks": 1,
#         "stats": {
#             "FlatArmorMod": 0,
#             "FlatAttackSpeedMod": 0,
#             "FlatBlockMod": 0,
#             "FlatCritChanceMod": 0,
#             "FlatCritDamageMod": 0,
#             "FlatEXPBonus": 0,
#             "FlatEnergyPoolMod": 0,
#             "FlatEnergyRegenMod": 0,
#             "FlatHPPoolMod": 0,
#             "FlatHPRegenMod": 0,
#             "FlatMPPoolMod": 0,
#             "FlatMPRegenMod": 0,
#             "FlatMagicDamageMod": 0,
#             "FlatMovementSpeedMod": 0,
#             "FlatPhysicalDamageMod": 0,
#             "FlatSpellBlockMod": 0,
#             "PercentArmorMod": 0,
#             "PercentAttackSpeedMod": 0,
#             "PercentBlockMod": 0,
#             "PercentCritChanceMod": 0,
#             "PercentCritDamageMod": 0,
#             "PercentDodgeMod": 0,
#             "PercentEXPBonus": 0,
#             "PercentHPPoolMod": 0,
#             "PercentHPRegenMod": 0,
#             "PercentLifeStealMod": 0,
#             "PercentMPPoolMod": 0,
#             "PercentMPRegenMod": 0,
#             "PercentMagicDamageMod": 0,
#             "PercentMovementSpeedMod": 0,
#             "PercentPhysicalDamageMod": 0,
#             "PercentSpellBlockMod": 0,
#             "PercentSpellVampMod": 0,
#             "rFlatArmorModPerLevel": 0,
#             "rFlatArmorPenetrationMod": 0,
#             "rFlatArmorPenetrationModPerLevel": 0,
#             "rFlatCritChanceModPerLevel": 0,
#             "rFlatCritDamageModPerLevel": 0,
#             "rFlatDodgeMod": 0,
#             "rFlatDodgeModPerLevel": 0,
#             "rFlatEnergyModPerLevel": 0,
#             "rFlatEnergyRegenModPerLevel": 0,
#             "rFlatGoldPer10Mod": 0,
#             "rFlatHPModPerLevel": 0,
#             "rFlatHPRegenModPerLevel": 0,
#             "rFlatMPModPerLevel": 0,
#             "rFlatMPRegenModPerLevel": 0,
#             "rFlatMagicDamageModPerLevel": 0,
#             "rFlatMagicPenetrationMod": 0,
#             "rFlatMagicPenetrationModPerLevel": 0,
#             "rFlatMovementSpeedModPerLevel": 0,
#             "rFlatPhysicalDamageModPerLevel": 0,
#             "rFlatSpellBlockModPerLevel": 0,
#             "rFlatTimeDeadMod": 0,
#             "rFlatTimeDeadModPerLevel": 0,
#             "rPercentArmorPenetrationMod": 0,
#             "rPercentArmorPenetrationModPerLevel": 0,
#             "rPercentAttackSpeedModPerLevel": 0,
#             "rPercentCooldownMod": 0,
#             "rPercentCooldownModPerLevel": 0,
#             "rPercentMagicPenetrationMod": 0,
#             "rPercentMagicPenetrationModPerLevel": 0,
#             "rPercentMovementSpeedModPerLevel": 0,
#             "rPercentTimeDeadMod": 0,
#             "rPercentTimeDeadModPerLevel": 0
#         },
#         "tags": []
#     },
#     "data": {
#         "1001": {
#             "colloq": ";",
#             "description": "<groupLimit>Limited to 1 pair of boots.</groupLimit><br><br><unique>UNIQUE Passive - Enhanced Movement:</unique> +25 Movement Speed",
#             "gold": {
#                 "base": 300,
#                 "purchasable": true,
#                 "sell": 210,
#                 "total": 300
#             },
#             "image": {
#                 "full": "1001.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 0,
#                 "y": 0
#             },
#             "into": [
#                 "3006",
#                 "3047",
#                 "3020",
#                 "3158",
#                 "3111",
#                 "3117",
#                 "3009"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Boots of Speed",
#             "plaintext": "Slightly increases Movement Speed",
#             "stats": {
#                 "FlatMovementSpeedMod": 25
#             },
#             "tags": [
#                 "Boots"
#             ]
#         },
#         "1004": {
#             "colloq": ";",
#             "description": "<stats><mana>+25% Base Mana Regen </mana></stats>",
#             "gold": {
#                 "base": 125,
#                 "purchasable": true,
#                 "sell": 88,
#                 "total": 125
#             },
#             "image": {
#                 "full": "1004.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 48,
#                 "y": 0
#             },
#             "into": [
#                 "3028",
#                 "3070",
#                 "3073",
#                 "3114"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Faerie Charm",
#             "plaintext": "Slightly increases Mana Regen",
#             "stats": {},
#             "tags": [
#                 "ManaRegen"
#             ]
#         },
#         "1006": {
#             "colloq": ";",
#             "description": "<stats>+50% Base Health Regen </stats>",
#             "gold": {
#                 "base": 150,
#                 "purchasable": true,
#                 "sell": 105,
#                 "total": 150
#             },
#             "image": {
#                 "full": "1006.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 96,
#                 "y": 0
#             },
#             "into": [
#                 "3077",
#                 "3801",
#                 "3194"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Rejuvenation Bead",
#             "plaintext": "Slightly increases Health Regen",
#             "stats": {},
#             "tags": [
#                 "HealthRegen"
#             ]
#         },
#         "1011": {
#             "colloq": ";",
#             "depth": 2,
#             "description": "<stats>+380 Health</stats>",
#             "from": [
#                 "1028"
#             ],
#             "gold": {
#                 "base": 600,
#                 "purchasable": true,
#                 "sell": 700,
#                 "total": 1000
#             },
#             "image": {
#                 "full": "1011.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 144,
#                 "y": 0
#             },
#             "into": [
#                 "3083",
#                 "3084",
#                 "3022",
#                 "3143",
#                 "3742"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Giant's Belt",
#             "plaintext": "Greatly increases Health",
#             "stats": {
#                 "FlatHPPoolMod": 380
#             },
#             "tags": [
#                 "Health"
#             ]
#         },
#         "1018": {
#             "colloq": ";",
#             "description": "<stats>+20% Critical Strike Chance</stats>",
#             "gold": {
#                 "base": 800,
#                 "purchasable": true,
#                 "sell": 560,
#                 "total": 800
#             },
#             "image": {
#                 "full": "1018.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 192,
#                 "y": 0
#             },
#             "into": [
#                 "3086",
#                 "3095",
#                 "3031",
#                 "3508"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Cloak of Agility",
#             "plaintext": "Increases critical strike chance",
#             "stats": {
#                 "FlatCritChanceMod": 0.2
#             },
#             "tags": [
#                 "CriticalStrike"
#             ]
#         },
#         "1026": {
#             "colloq": ";",
#             "description": "<stats>+40 Ability Power</stats>",
#             "gold": {
#                 "base": 850,
#                 "purchasable": true,
#                 "sell": 595,
#                 "total": 850
#             },
#             "image": {
#                 "full": "1026.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 240,
#                 "y": 0
#             },
#             "into": [
#                 "3135",
#                 "3029",
#                 "3151",
#                 "3027",
#                 "3100",
#                 "3102",
#                 "3116",
#                 "3165",
#                 "3285"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Blasting Wand",
#             "plaintext": "Moderately increases Ability Power",
#             "stats": {
#                 "FlatMagicDamageMod": 40
#             },
#             "tags": [
#                 "SpellDamage"
#             ]
#         },
#         "1027": {
#             "colloq": ";blue",
#             "description": "<stats><mana>+250 Mana</mana></stats>",
#             "gold": {
#                 "base": 350,
#                 "purchasable": true,
#                 "sell": 245,
#                 "total": 350
#             },
#             "image": {
#                 "full": "1027.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 288,
#                 "y": 0
#             },
#             "into": [
#                 "3057",
#                 "3070",
#                 "3010",
#                 "3024",
#                 "3073",
#                 "1402",
#                 "1414",
#                 "3802"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Sapphire Crystal",
#             "plaintext": "Increases Mana",
#             "stats": {
#                 "FlatMPPoolMod": 250
#             },
#             "tags": [
#                 "Mana"
#             ]
#         },
#         "1028": {
#             "colloq": ";red",
#             "description": "<stats>+150 Health</stats>",
#             "gold": {
#                 "base": 400,
#                 "purchasable": true,
#                 "sell": 280,
#                 "total": 400
#             },
#             "image": {
#                 "full": "1028.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 336,
#                 "y": 0
#             },
#             "into": [
#                 "1011",
#                 "3075",
#                 "3211",
#                 "3136",
#                 "3068",
#                 "3010",
#                 "3801",
#                 "3044",
#                 "3052",
#                 "3053",
#                 "3067",
#                 "3814",
#                 "3116",
#                 "3748",
#                 "3751",
#                 "3916"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Ruby Crystal",
#             "plaintext": "Increases Health",
#             "stats": {
#                 "FlatHPPoolMod": 150
#             },
#             "tags": [
#                 "Health"
#             ]
#         },
#         "1029": {
#             "colloq": ";",
#             "description": "<stats>+15 Armor</stats>",
#             "gold": {
#                 "base": 300,
#                 "purchasable": true,
#                 "sell": 210,
#                 "total": 300
#             },
#             "image": {
#                 "full": "1029.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 384,
#                 "y": 0
#             },
#             "into": [
#                 "3047",
#                 "1031",
#                 "3191",
#                 "3024",
#                 "3082",
#                 "3076",
#                 "3105"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Cloth Armor",
#             "plaintext": "Slightly increases Armor",
#             "stats": {
#                 "FlatArmorMod": 15
#             },
#             "tags": [
#                 "Armor"
#             ]
#         },
#         "1031": {
#             "colloq": ";",
#             "depth": 2,
#             "description": "<stats>+40 Armor</stats>",
#             "from": [
#                 "1029"
#             ],
#             "gold": {
#                 "base": 500,
#                 "purchasable": true,
#                 "sell": 560,
#                 "total": 800
#             },
#             "image": {
#                 "full": "1031.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 432,
#                 "y": 0
#             },
#             "into": [
#                 "3068",
#                 "3109",
#                 "3026",
#                 "3193",
#                 "3742"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Chain Vest",
#             "plaintext": "Greatly increases Armor",
#             "stats": {
#                 "FlatArmorMod": 40
#             },
#             "tags": [
#                 "Armor"
#             ]
#         },
#         "1033": {
#             "colloq": ";",
#             "description": "<stats>+25 Magic Resist</stats>",
#             "gold": {
#                 "base": 450,
#                 "purchasable": true,
#                 "sell": 315,
#                 "total": 450
#             },
#             "image": {
#                 "full": "1033.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 0,
#                 "y": 48
#             },
#             "into": [
#                 "3111",
#                 "3211",
#                 "1057",
#                 "3028",
#                 "3140",
#                 "3155",
#                 "3105",
#                 "3190",
#                 "3102",
#                 "3194"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Null-Magic Mantle",
#             "plaintext": "Slightly increases Magic Resist",
#             "stats": {
#                 "FlatSpellBlockMod": 25
#             },
#             "tags": [
#                 "SpellBlock"
#             ]
#         },
#         "1036": {
#             "colloq": ";",
#             "description": "<stats>+10 Attack Damage</stats>",
#             "gold": {
#                 "base": 350,
#                 "purchasable": true,
#                 "sell": 245,
#                 "total": 350
#             },
#             "image": {
#                 "full": "1036.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 48,
#                 "y": 48
#             },
#             "into": [
#                 "3077",
#                 "3123",
#                 "1053",
#                 "3155",
#                 "3134",
#                 "3179",
#                 "3035",
#                 "3044",
#                 "3052",
#                 "3072",
#                 "3133",
#                 "3144",
#                 "3161"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Long Sword",
#             "plaintext": "Slightly increases Attack Damage",
#             "stats": {
#                 "FlatPhysicalDamageMod": 10
#             },
#             "tags": [
#                 "Damage",
#                 "Lane"
#             ]
#         },
#         "1037": {
#             "colloq": ";",
#             "description": "<stats>+25 Attack Damage</stats>",
#             "gold": {
#                 "base": 875,
#                 "purchasable": true,
#                 "sell": 613,
#                 "total": 875
#             },
#             "image": {
#                 "full": "1037.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 96,
#                 "y": 48
#             },
#             "into": [
#                 "3124",
#                 "3004",
#                 "3008",
#                 "3031",
#                 "3036",
#                 "3053",
#                 "3074",
#                 "3814",
#                 "3139"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Pickaxe",
#             "plaintext": "Moderately increases Attack Damage",
#             "stats": {
#                 "FlatPhysicalDamageMod": 25
#             },
#             "tags": [
#                 "Damage"
#             ]
#         },
#         "1038": {
#             "colloq": ";bf",
#             "description": "<stats>+40 Attack Damage</stats>",
#             "gold": {
#                 "base": 1300,
#                 "purchasable": true,
#                 "sell": 910,
#                 "total": 1300
#             },
#             "image": {
#                 "full": "1038.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 144,
#                 "y": 48
#             },
#             "into": [
#                 "3095",
#                 "3026",
#                 "3031",
#                 "3072",
#                 "3161",
#                 "3508"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "B. F. Sword",
#             "plaintext": "Greatly increases Attack Damage",
#             "stats": {
#                 "FlatPhysicalDamageMod": 40
#             },
#             "tags": [
#                 "Damage"
#             ]
#         },
#         "1039": {
#             "colloq": ";jungle;Jungle",
#             "description": "<br><unique>UNIQUE Passive - Tooth:</unique> Damaging a monster with a spell or attack  steals 30 Health over 5 seconds and burns them for 60 magic damage. <mana>While in the jungle or river, regenerate up to 8 Mana per second based on your missing Mana.</mana> This item grants <font color='#99BBBB'><a href='SpecialJungleExperience'>Monster Hunter</a></font>. This item's healing will be increased by 50% when under 30% Health.<br><br><groupLimit>Limited to 1 Gold Income or Jungle item.</groupLimit>",
#             "effect": {
#                 "Effect1Amount": "60",
#                 "Effect2Amount": "30",
#                 "Effect3Amount": "5",
#                 "Effect4Amount": "8",
#                 "Effect5Amount": "0.3",
#                 "Effect6Amount": "0.5"
#             },
#             "gold": {
#                 "base": 350,
#                 "purchasable": true,
#                 "sell": 245,
#                 "total": 350
#             },
#             "image": {
#                 "full": "1039.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 192,
#                 "y": 48
#             },
#             "into": [
#                 "3706",
#                 "3715"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": false,
#                 "22": false
#             },
#             "name": "Hunter's Talisman",
#             "plaintext": "Provides damage against Monsters and Mana Regen in the Jungle",
#             "stats": {},
#             "tags": [
#                 "LifeSteal",
#                 "ManaRegen",
#                 "OnHit",
#                 "Jungle"
#             ]
#         },
#         "1041": {
#             "colloq": ";jungle;Jungle",
#             "description": "<stats>+10% Life Steal vs. Monsters</stats><br><br><unique>UNIQUE Passive - Nail:</unique> Basic attacks vs. Monsters deal 35 bonus damage on hit. This item grants <font color='#99BBBB'><a href='SpecialJungleExperience'>Monster Hunter</a></font>. This item's healing will be increased by 50% when under 30% Health.<br><br><groupLimit>Limited to 1 Gold Income or Jungle item.</groupLimit>",
#             "effect": {
#                 "Effect1Amount": "35",
#                 "Effect2Amount": "0.1",
#                 "Effect3Amount": "0.3",
#                 "Effect4Amount": "0.5"
#             },
#             "gold": {
#                 "base": 350,
#                 "purchasable": true,
#                 "sell": 245,
#                 "total": 350
#             },
#             "image": {
#                 "full": "1041.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 240,
#                 "y": 48
#             },
#             "into": [
#                 "3706",
#                 "3715"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": false,
#                 "22": false
#             },
#             "name": "Hunter's Machete",
#             "plaintext": "Provides damage and life steal versus Monsters",
#             "stats": {},
#             "tags": [
#                 "LifeSteal",
#                 "OnHit",
#                 "Jungle"
#             ]
#         },
#         "1042": {
#             "colloq": ";",
#             "description": "<stats>+12% Attack Speed</stats>",
#             "gold": {
#                 "base": 300,
#                 "purchasable": true,
#                 "sell": 210,
#                 "total": 300
#             },
#             "image": {
#                 "full": "1042.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 288,
#                 "y": 48
#             },
#             "into": [
#                 "1043",
#                 "3091",
#                 "3006",
#                 "2015",
#                 "3085",
#                 "3086",
#                 "3046",
#                 "3101"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Dagger",
#             "plaintext": "Slightly increases Attack Speed",
#             "stats": {
#                 "PercentAttackSpeedMod": 0.12
#             },
#             "tags": [
#                 "AttackSpeed"
#             ]
#         },
#         "1043": {
#             "colloq": ";",
#             "depth": 2,
#             "description": "<stats>+25% Attack Speed</stats><br><br><unique>UNIQUE Passive:</unique> Basic attacks deal an additional 15 physical damage on hit.",
#             "effect": {
#                 "Effect1Amount": "15"
#             },
#             "from": [
#                 "1042",
#                 "1042"
#             ],
#             "gold": {
#                 "base": 400,
#                 "purchasable": true,
#                 "sell": 700,
#                 "total": 1000
#             },
#             "image": {
#                 "full": "1043.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 336,
#                 "y": 48
#             },
#             "into": [
#                 "3091",
#                 "3153",
#                 "3124",
#                 "3675",
#                 "1416",
#                 "1419"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Recurve Bow",
#             "plaintext": "Greatly increases Attack Speed",
#             "stats": {
#                 "PercentAttackSpeedMod": 0.25
#             },
#             "tags": [
#                 "AttackSpeed",
#                 "OnHit"
#             ]
#         },
#         "1052": {
#             "colloq": ";amptome",
#             "description": "<stats>+20 Ability Power</stats>",
#             "gold": {
#                 "base": 435,
#                 "purchasable": true,
#                 "sell": 305,
#                 "total": 435
#             },
#             "image": {
#                 "full": "1052.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 384,
#                 "y": 48
#             },
#             "into": [
#                 "3108",
#                 "3191",
#                 "3136",
#                 "3135",
#                 "3145",
#                 "3113",
#                 "3124",
#                 "3116",
#                 "3673",
#                 "3802",
#                 "3916"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Amplifying Tome",
#             "plaintext": "Slightly increases Ability Power",
#             "stats": {
#                 "FlatMagicDamageMod": 20
#             },
#             "tags": [
#                 "SpellDamage"
#             ]
#         },
#         "1053": {
#             "colloq": ";",
#             "depth": 2,
#             "description": "<stats>+15 Attack Damage<br>+10% Life Steal</stats>",
#             "from": [
#                 "1036"
#             ],
#             "gold": {
#                 "base": 550,
#                 "purchasable": true,
#                 "sell": 630,
#                 "total": 900
#             },
#             "image": {
#                 "full": "1053.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 432,
#                 "y": 48
#             },
#             "into": [
#                 "3072",
#                 "3074",
#                 "3812",
#                 "3139",
#                 "3144",
#                 "3181"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Vampiric Scepter",
#             "plaintext": "Basic attacks restore Health",
#             "stats": {
#                 "FlatPhysicalDamageMod": 15,
#                 "PercentLifeStealMod": 0.1
#             },
#             "tags": [
#                 "Damage",
#                 "LifeSteal"
#             ]
#         },
#         "1054": {
#             "colloq": ";dshield",
#             "description": "<stats>+80 Health</stats><br><br><passive>Passive: </passive>Restores 6 Health every 5 seconds.<br><passive>Passive: </passive>Basic attacks deal an additional 5 physical damage to minions on hit.<br><unique>UNIQUE Passive:</unique> Regenerate up to 40 health over 8 seconds after taking damage from an enemy champion, based on percent missing health. (66% effective for Ranged Champions or Area of Effect and Periodic damage triggers)",
#             "effect": {
#                 "Effect1Amount": "8",
#                 "Effect2Amount": "5",
#                 "Effect3Amount": "40",
#                 "Effect4Amount": "0.66"
#             },
#             "gold": {
#                 "base": 450,
#                 "purchasable": true,
#                 "sell": 180,
#                 "total": 450
#             },
#             "image": {
#                 "full": "1054.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 0,
#                 "y": 96
#             },
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Doran's Shield",
#             "plaintext": "Good defensive starting item",
#             "stats": {
#                 "FlatHPPoolMod": 80,
#                 "FlatHPRegenMod": 1.2
#             },
#             "tags": [
#                 "Health",
#                 "HealthRegen",
#                 "Lane"
#             ]
#         },
#         "1055": {
#             "colloq": ";dblade",
#             "description": "<stats>+8 Attack Damage<br>+80 Health<br>+3% Life Steal</stats>",
#             "effect": {
#                 "Effect1Amount": "10"
#             },
#             "gold": {
#                 "base": 450,
#                 "purchasable": true,
#                 "sell": 180,
#                 "total": 450
#             },
#             "image": {
#                 "full": "1055.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 48,
#                 "y": 96
#             },
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Doran's Blade",
#             "plaintext": "Good starting item for attackers",
#             "stats": {
#                 "FlatHPPoolMod": 80,
#                 "FlatPhysicalDamageMod": 8,
#                 "PercentLifeStealMod": 0.03
#             },
#             "tags": [
#                 "Damage",
#                 "Health",
#                 "Lane",
#                 "LifeSteal"
#             ]
#         },
#         "1056": {
#             "colloq": ";dring",
#             "description": "<stats>+60 Health<br>+15 Ability Power<br><mana>+5 Mana per 5 seconds</mana></stats><br><br><passive>Passive: </passive>Basic attacks deal an additional 5 physical damage to minions on hit.",
#             "effect": {
#                 "Effect1Amount": "0",
#                 "Effect2Amount": "5"
#             },
#             "gold": {
#                 "base": 400,
#                 "purchasable": true,
#                 "sell": 160,
#                 "total": 400
#             },
#             "image": {
#                 "full": "1056.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 96,
#                 "y": 96
#             },
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Doran's Ring",
#             "plaintext": "Good starting item for casters",
#             "stats": {
#                 "FlatHPPoolMod": 60,
#                 "FlatMagicDamageMod": 15
#             },
#             "tags": [
#                 "Health",
#                 "Lane",
#                 "ManaRegen",
#                 "SpellDamage"
#             ]
#         },
#         "1057": {
#             "colloq": ";",
#             "depth": 2,
#             "description": "<stats>+40 Magic Resist</stats>",
#             "from": [
#                 "1033"
#             ],
#             "gold": {
#                 "base": 270,
#                 "purchasable": true,
#                 "sell": 504,
#                 "total": 720
#             },
#             "image": {
#                 "full": "1057.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 144,
#                 "y": 96
#             },
#             "into": [
#                 "3091",
#                 "3193",
#                 "3001"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Negatron Cloak",
#             "plaintext": "Moderately increases Magic Resist",
#             "stats": {
#                 "FlatSpellBlockMod": 40
#             },
#             "tags": [
#                 "SpellBlock"
#             ]
#         },
#         "1058": {
#             "colloq": ";nlr",
#             "description": "<stats>+60 Ability Power</stats>",
#             "gold": {
#                 "base": 1250,
#                 "purchasable": true,
#                 "sell": 875,
#                 "total": 1250
#             },
#             "image": {
#                 "full": "1058.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 192,
#                 "y": 96
#             },
#             "into": [
#                 "3089",
#                 "3907"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Needlessly Large Rod",
#             "plaintext": "Greatly increases Ability Power",
#             "stats": {
#                 "FlatMagicDamageMod": 60
#             },
#             "tags": [
#                 "SpellDamage"
#             ]
#         },
#         "1082": {
#             "colloq": ";Noxian",
#             "description": "<stats>+10 Ability Power<br>+25% Increased Healing from Potions<br><mana>+100 Mana</mana></stats><br><br><unique>UNIQUE Passive - Dread:</unique> Grants +3 Ability Power per Glory.  <br><unique>UNIQUE Passive - Do or Die:</unique> Grants 2 Glory for a champion kill or 1 Glory for an assist, up to 10 Glory total. Lose 4 Glory on death.",
#             "effect": {
#                 "Effect1Amount": "0.25",
#                 "Effect2Amount": "2",
#                 "Effect3Amount": "1",
#                 "Effect4Amount": "10",
#                 "Effect5Amount": "3",
#                 "Effect6Amount": "4"
#             },
#             "gold": {
#                 "base": 350,
#                 "purchasable": true,
#                 "sell": 140,
#                 "total": 350
#             },
#             "image": {
#                 "full": "1082.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 240,
#                 "y": 96
#             },
#             "into": [
#                 "3041"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": false,
#                 "22": false
#             },
#             "name": "Dark Seal",
#             "plaintext": "Provides Ability Power and Mana.  Increases in power as you kill enemies.",
#             "stats": {
#                 "FlatMPPoolMod": 100,
#                 "FlatMagicDamageMod": 10
#             },
#             "tags": [
#                 "HealthRegen",
#                 "SpellDamage",
#                 "Mana",
#                 "Lane"
#             ]
#         },
#         "1083": {
#             "colloq": ";dblade",
#             "description": "<stats>+7 Attack Damage<br>+3 Life on Hit</stats><br><br><unique>UNIQUE Passive:</unique> Killing a lane minion grants 1 additional Gold. Killing 100 lane minions grants an additional 350 bonus gold immediately and disables this passive.",
#             "effect": {
#                 "Effect1Amount": "3",
#                 "Effect2Amount": "1",
#                 "Effect3Amount": "100",
#                 "Effect4Amount": "350"
#             },
#             "gold": {
#                 "base": 450,
#                 "purchasable": true,
#                 "sell": 180,
#                 "total": 450
#             },
#             "image": {
#                 "full": "1083.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 288,
#                 "y": 96
#             },
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Cull",
#             "plaintext": "Provides damage and Life Steal on hit - Killing minions grant bonus Gold",
#             "stats": {
#                 "FlatPhysicalDamageMod": 7
#             },
#             "tags": [
#                 "Damage",
#                 "LifeSteal",
#                 "Lane"
#             ]
#         },
#         "1400": {
#             "colloq": "",
#             "depth": 3,
#             "description": "<stats>+60 Attack Damage<br>+10% Cooldown Reduction</stats><br><br><groupLimit>Limited to 1 Gold Income or Jungle item.</groupLimit>",
#             "effect": {
#                 "Effect10Amount": "0",
#                 "Effect11Amount": "0",
#                 "Effect12Amount": "0.3",
#                 "Effect13Amount": "0.5",
#                 "Effect1Amount": "80",
#                 "Effect2Amount": "30",
#                 "Effect3Amount": "5",
#                 "Effect4Amount": "8",
#                 "Effect5Amount": "40",
#                 "Effect6Amount": "0.1",
#                 "Effect7Amount": "2",
#                 "Effect8Amount": "-0.2",
#                 "Effect9Amount": "0"
#             },
#             "from": [
#                 "3133",
#                 "3706"
#             ],
#             "gold": {
#                 "base": 525,
#                 "purchasable": true,
#                 "sell": 1838,
#                 "total": 2625
#             },
#             "hideFromAll": true,
#             "image": {
#                 "full": "1400.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 336,
#                 "y": 96
#             },
#             "maps": {
#                 "11": true,
#                 "12": false,
#                 "22": false
#             },
#             "name": "Enchantment: Warrior",
#             "plaintext": "Grants Attack Damage and Cooldown Reduction",
#             "stats": {
#                 "FlatPhysicalDamageMod": 60
#             },
#             "tags": []
#         },
#         "1401": {
#             "colloq": "",
#             "depth": 3,
#             "description": "<stats>+300 Health<br>+15% Bonus Health</stats><br><br><unique>UNIQUE Passive - Immolate:</unique> While in combat, burns nearby enemies for <scaleLevel>[12 to 29]</scaleLevel> magic damage a second. Once every 12 seconds, your next immobilizing spell deals <scaleLevel>[12 to 29]</scaleLevel> <scaleHealth>(+3% Your Bonus HP)</scaleHealth> bonus magic damage and releases a fire nova that also deals that bonus damage around you. Immolate's damage is increased by 300% damage to minions and monsters.<br><groupLimit>Limited to 1 Gold Income or Jungle item.</groupLimit>",
#             "effect": {
#                 "Effect10Amount": "0",
#                 "Effect11Amount": "0",
#                 "Effect12Amount": "0.3",
#                 "Effect13Amount": "0.5",
#                 "Effect1Amount": "80",
#                 "Effect2Amount": "30",
#                 "Effect3Amount": "5",
#                 "Effect4Amount": "8",
#                 "Effect5Amount": "40",
#                 "Effect6Amount": "0.1",
#                 "Effect7Amount": "2",
#                 "Effect8Amount": "-0.2",
#                 "Effect9Amount": "0"
#             },
#             "from": [
#                 "3751",
#                 "3706"
#             ],
#             "gold": {
#                 "base": 600,
#                 "purchasable": true,
#                 "sell": 1750,
#                 "total": 2500
#             },
#             "hideFromAll": true,
#             "image": {
#                 "full": "1401.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 384,
#                 "y": 96
#             },
#             "maps": {
#                 "11": true,
#                 "12": false,
#                 "22": false
#             },
#             "name": "Enchantment: Cinderhulk",
#             "plaintext": "Grants Health and Immolate Aura",
#             "stats": {
#                 "FlatHPPoolMod": 300
#             },
#             "tags": []
#         },
#         "1402": {
#             "colloq": "",
#             "depth": 3,
#             "description": "<stats>+80 Ability Power<br>+10% Cooldown Reduction<br><mana>+300 Mana</mana></stats><br><br><unique>UNIQUE Passive - Echo:</unique> Gain charges upon moving or casting. At 100 charges, the next damaging spell hit expends all charges to deal 60 (+10% of Ability Power) bonus magic damage to up to 4 targets on hit.<br><br>This effect deals 250% damage to Large Monsters. Hitting a Large Monster with this effect will restore 25% of your missing Mana.<br><br><groupLimit>Limited to 1 Gold Income or Jungle item.</groupLimit>",
#             "effect": {
#                 "Effect10Amount": "0",
#                 "Effect11Amount": "0",
#                 "Effect12Amount": "0.3",
#                 "Effect13Amount": "0.5",
#                 "Effect1Amount": "80",
#                 "Effect2Amount": "30",
#                 "Effect3Amount": "5",
#                 "Effect4Amount": "8",
#                 "Effect5Amount": "40",
#                 "Effect6Amount": "0.1",
#                 "Effect7Amount": "2",
#                 "Effect8Amount": "-0.2",
#                 "Effect9Amount": "0"
#             },
#             "from": [
#                 "3108",
#                 "1027",
#                 "3706"
#             ],
#             "gold": {
#                 "base": 250,
#                 "purchasable": true,
#                 "sell": 1750,
#                 "total": 2500
#             },
#             "hideFromAll": true,
#             "image": {
#                 "full": "1402.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 432,
#                 "y": 96
#             },
#             "maps": {
#                 "11": true,
#                 "12": false,
#                 "22": false
#             },
#             "name": "Enchantment: Runic Echoes",
#             "plaintext": "Grants Ability Power and periodically empowers your Spells",
#             "stats": {
#                 "FlatMPPoolMod": 300,
#                 "FlatMagicDamageMod": 80
#             },
#             "tags": []
#         },
#         "1412": {
#             "colloq": "",
#             "depth": 3,
#             "description": "<stats>+60 Attack Damage<br>+10% Cooldown Reduction</stats><br><br><groupLimit>Limited to 1 Gold Income or Jungle item.</groupLimit>",
#             "effect": {
#                 "Effect10Amount": "0.2",
#                 "Effect11Amount": "0.1",
#                 "Effect12Amount": "0.3",
#                 "Effect13Amount": "0.5",
#                 "Effect1Amount": "80",
#                 "Effect2Amount": "30",
#                 "Effect3Amount": "5",
#                 "Effect4Amount": "8",
#                 "Effect5Amount": "40",
#                 "Effect6Amount": "4",
#                 "Effect7Amount": "3",
#                 "Effect8Amount": "18",
#                 "Effect9Amount": "2"
#             },
#             "from": [
#                 "3133",
#                 "3715"
#             ],
#             "gold": {
#                 "base": 525,
#                 "purchasable": true,
#                 "sell": 1838,
#                 "total": 2625
#             },
#             "hideFromAll": true,
#             "image": {
#                 "full": "1412.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 0,
#                 "y": 144
#             },
#             "maps": {
#                 "11": true,
#                 "12": false,
#                 "22": false
#             },
#             "name": "Enchantment: Warrior",
#             "plaintext": "Grants Attack Damage and Cooldown Reduction",
#             "stats": {
#                 "FlatPhysicalDamageMod": 60
#             },
#             "tags": []
#         },
#         "1413": {
#             "colloq": "",
#             "depth": 3,
#             "description": "<stats>+300 Health<br>+15% Bonus Health</stats><br><br><unique>UNIQUE Passive - Immolate:</unique> While in combat, burns nearby enemies for <scaleLevel>[12 to 29]</scaleLevel> magic damage a second. Once every 12 seconds, your next immobilizing spell deals <scaleLevel>[12 to 29]</scaleLevel> <scaleHealth>(+3% Your Bonus HP)</scaleHealth> bonus magic damage and releases a fire nova that also deals that bonus damage around you. Immolate's damage is increased by 300% damage to minions and monsters.<br><groupLimit>Limited to 1 Gold Income or Jungle item.</groupLimit>",
#             "effect": {
#                 "Effect10Amount": "0.2",
#                 "Effect11Amount": "0.1",
#                 "Effect12Amount": "0.3",
#                 "Effect13Amount": "0.4",
#                 "Effect1Amount": "80",
#                 "Effect2Amount": "30",
#                 "Effect3Amount": "5",
#                 "Effect4Amount": "8",
#                 "Effect5Amount": "40",
#                 "Effect6Amount": "4",
#                 "Effect7Amount": "3",
#                 "Effect8Amount": "18",
#                 "Effect9Amount": "2"
#             },
#             "from": [
#                 "3751",
#                 "3715"
#             ],
#             "gold": {
#                 "base": 600,
#                 "purchasable": true,
#                 "sell": 1750,
#                 "total": 2500
#             },
#             "hideFromAll": true,
#             "image": {
#                 "full": "1413.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item0.png",
#                 "w": 48,
#                 "x": 48,
#                 "y": 144
#             },
#             "maps": {
#                 "11": true,
#                 "12": false,
#                 "22": false
#             },
# ...
#         "3901": {
#             "colloq": "",
#             "consumeOnFull": true,
#             "consumed": true,
#             "description": "Requires 500 Silver Serpents.<br><br><unique>UNIQUE Passive:</unique> Cannon Barrage fires at an increasing rate over time (additional 6 waves over the duration).",
#             "gold": {
#                 "base": 0,
#                 "purchasable": true,
#                 "sell": 0,
#                 "total": 0
#             },
#             "image": {
#                 "full": "3901.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item2.png",
#                 "w": 48,
#                 "x": 384,
#                 "y": 144
#             },
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Fire at Will",
#             "plaintext": "Cannon Barrage gains extra waves",
#             "requiredChampion": "Gangplank",
#             "stats": {},
#             "tags": []
#         },
#         "3902": {
#             "colloq": "",
#             "consumeOnFull": true,
#             "consumed": true,
#             "description": "Requires 500 Silver Serpents.<br><br><unique>UNIQUE Passive:</unique> Cannon Barrage additionally fires a mega-cannonball at center of the Barrage, dealing 300% true damage and slowing them by 60% for 1.5 seconds. ",
#             "gold": {
#                 "base": 0,
#                 "purchasable": true,
#                 "sell": 0,
#                 "total": 0
#             },
#             "image": {
#                 "full": "3902.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item2.png",
#                 "w": 48,
#                 "x": 432,
#                 "y": 144
#             },
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Death's Daughter",
#             "plaintext": "Cannon Barrage fires a mega-cannonball",
#             "requiredChampion": "Gangplank",
#             "stats": {},
#             "tags": []
#         },
#         "3903": {
#             "colloq": "",
#             "consumeOnFull": true,
#             "consumed": true,
#             "description": "Requires 500 Silver Serpents.<br><br><unique>UNIQUE Passive:</unique> Allies in the Cannon Barrage gain 30% Movement Speed for 2 seconds.",
#             "gold": {
#                 "base": 0,
#                 "purchasable": true,
#                 "sell": 0,
#                 "total": 0
#             },
#             "image": {
#                 "full": "3903.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item2.png",
#                 "w": 48,
#                 "x": 0,
#                 "y": 192
#             },
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Raise Morale",
#             "plaintext": "Cannon Barrage hastes allies",
#             "requiredChampion": "Gangplank",
#             "stats": {},
#             "tags": []
#         },
#         "3905": {
#             "colloq": ";spooky;spooky ghosts",
#             "depth": 3,
#             "description": "<stats>+70 Ability Power<br>+7% Movement Speed<br>+10% Cooldown Reduction</stats><br><br><unique>UNIQUE Active - Spectral Pursuit:</unique> Summons 2 spooky ghosts that hunt down nearby champions, revealing and Haunting them on contact. <br><br>Haunted enemies are slowed by 40% for up to 5 seconds based on the distance the ghosts travel. (90 second cooldown).",
#             "effect": {
#                 "Effect10Amount": "60",
#                 "Effect11Amount": "150",
#                 "Effect12Amount": "0.1",
#                 "Effect13Amount": "40",
#                 "Effect14Amount": "5",
#                 "Effect15Amount": "2",
#                 "Effect16Amount": "7",
#                 "Effect1Amount": "10",
#                 "Effect2Amount": "35",
#                 "Effect3Amount": "8",
#                 "Effect4Amount": "0.2",
#                 "Effect5Amount": "0.5",
#                 "Effect6Amount": "10",
#                 "Effect7Amount": "2100",
#                 "Effect8Amount": "10",
#                 "Effect9Amount": "90"
#             },
#             "from": [
#                 "3108",
#                 "3113"
#             ],
#             "gold": {
#                 "base": 650,
#                 "purchasable": true,
#                 "sell": 1680,
#                 "total": 2400
#             },
#             "image": {
#                 "full": "3905.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item2.png",
#                 "w": 48,
#                 "x": 48,
#                 "y": 192
#             },
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Twin Shadows",
#             "plaintext": "Increases Ability Power and Movement Speed",
#             "stats": {
#                 "FlatMagicDamageMod": 70,
#                 "PercentMovementSpeedMod": 0.07
#             },
#             "tags": [
#                 "SpellDamage",
#                 "Active",
#                 "CooldownReduction",
#                 "Slow",
#                 "NonbootsMovement"
#             ]
#         },
#         "3907": {
#             "colloq": "",
#             "depth": 3,
#             "description": "<stats>+120 Ability Power<br>+10% Movement Speed<br></stats><br><unique>UNIQUE Passive:</unique> Nearby allied and enemy spellcasts charge Spellbinder up to a cap (100 maximum). <br><unique>UNIQUE Active:</unique> Gain a maximum of 80 Ability Power and 50% decaying Movement Speed for 4 seconds. <br><br>Each spellcast stored contributes +0.8 Ability Power and +0.5% Movement Speed to the effect. (60 second cooldown).",
#             "effect": {
#                 "Effect10Amount": "120",
#                 "Effect11Amount": "1800",
#                 "Effect1Amount": "10",
#                 "Effect2Amount": "100",
#                 "Effect3Amount": "0.5",
#                 "Effect4Amount": "4",
#                 "Effect5Amount": "0.8",
#                 "Effect6Amount": "60",
#                 "Effect7Amount": "4",
#                 "Effect8Amount": "80",
#                 "Effect9Amount": "50"
#             },
#             "from": [
#                 "1058",
#                 "3113"
#             ],
#             "gold": {
#                 "base": 800,
#                 "purchasable": true,
#                 "sell": 2030,
#                 "total": 2900
#             },
#             "image": {
#                 "full": "3907.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item2.png",
#                 "w": 48,
#                 "x": 96,
#                 "y": 192
#             },
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Spellbinder",
#             "plaintext": "Stores nearby spellcasts and can consume them to grant Movement Speed and Ability Power.",
#             "stats": {
#                 "FlatMagicDamageMod": 120,
#                 "PercentMovementSpeedMod": 0.1
#             },
#             "tags": [
#                 "SpellDamage",
#                 "Active",
#                 "NonbootsMovement"
#             ]
#         },
#         "3916": {
#             "colloq": "",
#             "depth": 2,
#             "description": "<stats>+20 Ability Power<br>+200 Health</stats><br><br><unique>UNIQUE Passive - Touch of Death:</unique> +15 <a href='FlatMagicPen'>Magic Penetration</a>",
#             "effect": {
#                 "Effect1Amount": "15"
#             },
#             "from": [
#                 "1028",
#                 "1052"
#             ],
#             "gold": {
#                 "base": 765,
#                 "purchasable": true,
#                 "sell": 1120,
#                 "total": 1600
#             },
#             "image": {
#                 "full": "3916.png",
#                 "group": "item",
#                 "h": 48,
#                 "sprite": "item2.png",
#                 "w": 48,
#                 "x": 144,
#                 "y": 192
#             },
#             "into": [
#                 "3165"
#             ],
#             "maps": {
#                 "11": true,
#                 "12": true,
#                 "22": false
#             },
#             "name": "Oblivion Orb",
#             "plaintext": "Increases magic damage",
#             "stacks": 0,
#             "stats": {
#                 "FlatHPPoolMod": 200,
#                 "FlatMagicDamageMod": 20
#             },
#             "tags": [
#                 "Health",
#                 "MagicPenetration",
#                 "SpellDamage"
#             ]
#         }
#     },
#     "groups": [
#         {
#             "MaxGroupOwnable": "1",
#             "id": "HuntersTalismanGroup"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "HuntersMacheteGroup"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "BaseJungleItems"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "Boots"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "BootsOfSpeed"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "BootsWithoutActives"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "BuildsFromStopwatchGroup"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "Consumable"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "Default"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "DoransItems"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "Elixir"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "GangplankRUpgrade01"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "GangplankRUpgrade02"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "GangplankRUpgrade03"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "GoldItems"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "GuardianItems"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "ItemGroupSwapToSummonerDot"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "ItemGroupSwapToSummonerFlash"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "ItemGroupSwapToSummonerHaste"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "ItemGroupSwapToSummonerHeal"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "ItemGroupSwapToSummonerSmite"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "ItemGroupSwapToSummonerTeleport"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "JungleEnchantments"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "JungleItems"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "LegendaryClearingItems"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "LethalityItems"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "NewDoransItems"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "NonItem"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "OdysseySustainItems"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "OrnnItems"
#         },
#         {
#             "MaxGroupOwnable": "0",
#             "id": "PerksElixir"
#         },
#         {
#             "MaxGroupOwnable": "0",
#             "id": "PerksElixirAdvanced"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "Potion"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "SLIMEStarterItems"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "SiegeEmergencyShieldGroup"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "SiegeFlashZoneGroup"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "SiegeLaserAffixGroup"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "SiegeMissileBarrageGroup"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "SiegePortableBarracksGroup"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "SiegeRefundGroup"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "SiegeShieldGeneratorGroup"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "SiegeSniperCannonGroup"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "SiegeTeleportPadGroup"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "SiegeTimefieldGroup"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "SightstoneActiveItems"
#         },
#         {
#             "MaxGroupOwnable": "0",
#             "id": "SightstoneDisableGroup"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "StopwatchGroup"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "TearItems"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "TheBlackSpear"
#         },
#         {
#             "MaxGroupOwnable": "0",
#             "id": "TotalBiscuit"
#         },
#         {
#             "MaxGroupOwnable": "-1",
#             "id": "Trinket"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "ViktorHexCore"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "WardGreen"
#         },
#         {
#             "MaxGroupOwnable": "1",
#             "id": "WardPink"
#         }
#     ],
#     "tree": [
#         {
#             "header": "START",
#             "tags": [
#                 "LANE",
#                 "JUNGLE"
#             ]
#         },
#         {
#             "header": "TOOLS",
#             "tags": [
#                 "GOLDPER",
#                 "CONSUMABLE",
#                 "VISION"
#             ]
#         },
#         {
#             "header": "DEFENSE",
#             "tags": [
#                 "HEALTH",
#                 "HEALTHREGEN",
#                 "ARMOR",
#                 "SPELLBLOCK"
#             ]
#         },
#         {
#             "header": "ATTACK",
#             "tags": [
#                 "LIFESTEAL",
#                 "CRITICALSTRIKE",
#                 "ATTACKSPEED",
#                 "DAMAGE"
#             ]
#         },
#         {
#             "header": "MAGIC",
#             "tags": [
#                 "MANA",
#                 "SPELLDAMAGE",
#                 "COOLDOWNREDUCTION",
#                 "MANAREGEN"
#             ]
#         },
#         {
#             "header": "MOVEMENT",
#             "tags": [
#                 "BOOTS",
#                 "NONBOOTSMOVEMENT"
#             ]
#         },
#         {
#             "header": "UNCATEGORIZED",
#             "tags": [
#                 "ACTIVE",
#                 "MAGICPENETRATION",
#                 "ARMORPENETRATION",
#                 "AURA",
#                 "ONHIT",
#                 "TRINKET",
#                 "SLOW",
#                 "STEALTH",
#                 "SPELLVAMP",
#                 "TENACITY"
#             ]
#         }
#     ],
#     "type": "item",
#     "version": "10.12.1"
# }
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6211d436676c> in <module>
#      42 version = getCurrentVersion()
#      43 GetDDragonData_Champions()
# ---> 44 GetDDragonData_Items()
#
# <ipython-input-1-6211d436676c> in GetDDragonData_Items()
#      33     for key,item in allItemsRawData['data'].items():
#      34         ItemIdToName[int(key)] = item['name']
# ---> 35     print(ItemToToName)
#      36     return ItemIdToName
#      37
#
# NameError: name 'ItemToToName' is not defined

# %%
import requests
import json
import time
import threading

apiKey = config.api_key

# Riot Api Endpoints See: Riot Developer Portal
riotApi_GetSummonerInfo_BySummonerName = "https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/"
riotApi_GetSummonerMatchHistory_BySummonerId = "https://na1.api.riotgames.com/lol/match/v4/matchlists/by-account/"
riotApi_Get_Matches_ByGameId = "https://na1.api.riotgames.com/lol/match/v4/matches/"
riotApi_GET_ChampionMasteries_BySummonerId = "https://na1.api.riotgames.com/lol/champion-mastery/v4/champion-masteries/by-summoner/"

#Batch Queries
#SummonerNamesList = ["Learn2Program", "Ali00P", "PorkPounder", "Redmarmalade", "LonelySupport"]
ScottAccountNameList = ["Learn2Program", "LonelySupport"]
ScottAccountIdList = []

#filled probably by a inputbox
summonerName = ""
summonerId = ""
accountId = ""
gameIdList = []
summonerIdList = []

matchesValuesOnlyList = []
SummonerInfoDictionary = {}

#return values for each function call
GameObject = {}
matchList = []
gameInfoList = []
AllGames = []
fullGame =[]

def MakeApiCall(query):
    # Check Limiter for # of Calls 
    # 20 requests every 1 second
    # 100 requests every 2 minutes
    response = requests.get(query)
    return response.json()

def GetAll_ChampionMasteries_ForOne_SummonerId(domain, summId, key):
    queryBuilder = "{0}{1}?api_key={2}"
    query = queryBuilder.format(domain, summId, key)
    championMasteryData = MakeApiCall(query)
    Game_OverWriteDataToFile("SummonerId_"+summId, championMasteryData)
    #MongoDbResponse = db.ChampionMastery.insert_one(championMasteryData)
    #print("Successfully Stored into MongoDB... MongoDBResponse: ", MongoDbResponse)
    #Pull championId : value
    #Pull championPoints : value        <--MasteryPoints
    #Pull summonerId : value            <-- who it belongs too

def GetAll_ChampionMasteries_ForAllAccounts_InAccountIDList(domain, listOfAccountId, key):
    for accid in listOfAccountId:
        queryBuilder = "{0}{1}?api_key={2}"
        query = queryBuilder.format(domain, accid, key)
        championMasteryData = MakeApiCall(query)
        #result = db.ChampionMastery.insert_one(championMasteryData)
        print(result)
        print("Successfully added All ChampionMastery from Specific Id", accid)
        time.sleep(0.5)

def GetAll_AccountIds_ForAllAccountNames(domain, ScottAccountNameList, key):
    for name in ScottAccountNameList:
        queryBuilder = "{0}{1}?api_key={2}"
        query = queryBuilder.format(domain, name, key)
        summonerInfo = MakeApiCall(query)
        print("Summoner Name: " + name)
        summonerName = summonerInfo['name']
        summonerId = summonerInfo['id']
        accountId = summonerInfo['accountId']
        if summonerId not in summonerIdList:
            summonerIdList.append(summonerId)
        if accountId not in ScottAccountIdList:
            ScottAccountIdList.append(accountId)
        time.sleep(0.5)
    for accountId in ScottAccountIdList:
        #TODO: Move Function call for Readability
        GetMatches(riotApi_GetSummonerMatchHistory_BySummonerId, accountId, apiKey)
        time.sleep(0.5)
    print("Finished getting all Matches for every Account Id, in ScottAccountIdList... Line:81")
    #GetAll_ChampionMasteries_ForAllAccounts_InAccountIDList(riotApi_GET_ChampionMasteries_BySummonerId, ScottAccountIdList, apiKey)

def GetMatches(domain, accId, key):
    queryBuilder = "{0}{1}?api_key={2}"
    query = queryBuilder.format(domain, accId, key)
    summonerMatchInfo = MakeApiCall(query)
                                                #Loops through all 100 Matches
    for match in summonerMatchInfo["matches"]:                             
        gameIdList.append(match['gameId'])      #gets all Gameid's and adds them to the GameIdList
                                                #Call GameID and pass ApiCallQuery with the GameIdList
        #Writes all GameId's to a file with AccountID as Game. For Matching
    #Game_OverWriteDataToFile("GameIDList_"+str(accId), gameIdList)
    #TODO: Move Function call for Readability
    GetGameInfoById(riotApi_Get_Matches_ByGameId, apiKey, gameIdList)

def GetSummonerInfo_Using_SummonerName(domain, key, name):
    queryBuilder = "{0}{1}?api_key={2}"
    query = queryBuilder.format(domain, name, key)
    summonerInfo = MakeApiCall(query)
    #mongodbResultResponse = db.SummonerInfo.insert_one(summonerInfo)
    #print("\tSuccessfully Stored One SummonerInfo Into SummonerInfo-Collection... \n\tMongoDbResultResponse: ", mongodbResultResponse)
    # Store Summoner Id for later:
    summonerId = summonerInfo['id']
    summonerName = summonerInfo['name']
    accountId = summonerInfo['accountId']
    summonerLevel = summonerInfo['summonerLevel']
    if summonerId not in summonerIdList:
        summonerIdList.append(summonerId)
    if accountId not in ScottAccountIdList:
        ScottAccountIdList.append(accountId)
    if (summonerId not in SummonerInfoDictionary) or (accountId not in SummonerInfoDictionary) or (summonerLevel not in SummonerInfoDictionary) or (summonerName not in SummonerInfoDictionary):
        SummonerInfoDictionary.update({'name': summonerName, 'summonerId': summonerId, 'accountId': accountId, 'summonerLevel': summonerLevel})
    Game_OverWriteDataToFile(summonerName, SummonerInfoDictionary)

    # Using List of AccountID's
    #GetAll_ChampionMasteries_ForAllAccounts_InAccountIDList(riotApi_GET_ChampionMasteries_BySummonerId, ScottAccountList, apiKey)

    #   Using For-Loop SummonerIDs List, Make API Call Each Iteration
    # for summonerId in summonerIdList:
    #     GetAll_ChampionMasteries_ForOne_SummonerId(riotApi_GET_ChampionMasteries_BySummonerId, summonerId, apiKey)
    # print("finished inserting all Summoner's ChampionMasteries")

def GetGameInfoById(domain, key, gameIdList):
    #TODO For each loop this later
    #get last 10 matches
    ID_Counter = 0 
    for gameId in gameIdList[:9]:
        queryBuilder = "{0}{1}?api_key={2}"
        query = queryBuilder.format(domain, gameId, key)
        fullGameInfo = MakeApiCall(query)
        ID_Counter += ID_Counter + 1
        time.sleep(0.4)
         #TODO: Move Function call for Readability
        GetsGameDetailsForFrontend(fullGameInfo, ID_Counter)
    #Game_OverWriteDataToFile("GameId_"+str(gameId)+"_GameNum_0", fullGameInfo)

    # GIVES EVERY GAME FOR SUMMONER
def GetsGameDetailsForFrontend(fullGameInfo, counter):
    gameId = fullGameInfo['gameId']
    gameDuration = fullGameInfo['gameDuration']
    participantAccountInfo = fullGameInfo['participantIdentities']
    participants = fullGameInfo['participants']
    teams = fullGameInfo['teams']
    GameObject.update({'id':counter, 'gameId':gameId, 'gameDuration':gameDuration, 'participantAccountInfo':participantAccountInfo, 'participants':participants, 'teams':teams})
    AllGames.append(GameObject)
    #GIVES EVERY GAME FOR THAT SUMMONER

# %%
GetAll_AccountIds_ForAllAccountNames(riotApi_GetSummonerInfo_BySummonerName, ScottAccountNameList, apiKey)
# Out:
# Summoner Name: Learn2Program
# Summoner Name: LonelySupport
# Finished getting all Matches for every Account Id, in ScottAccountIdList... Line:81

# %%
# Out:
# {'id': 511,
#  'gameId': 3463026702,
#  'gameDuration': 990,
#  'participantAccountInfo': [{'participantId': 1,
#    'player': {'platformId': 'NA',
#     'accountId': '8S35WQ1He0eaTUnt0PsCi72pp2cBPorPdhHrSwYnp2HMJg',
#     'summonerName': 'IQARUS',
#     'summonerId': '4lDgPmwuVJcMVWK5fFROZWPo4jruz4y2mJXyY1gNzCfCYiE',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': '8S35WQ1He0eaTUnt0PsCi72pp2cBPorPdhHrSwYnp2HMJg',
#     'matchHistoryUri': '/v1/stats/player_history/NA/33644000',
#     'profileIcon': 21}},
#   {'participantId': 2,
#    'player': {'platformId': 'NA',
#     'accountId': 'V7_mBDpQkmRq_UxzOaBXs4OMa1-zrmvsVXDGex-eQOp4Dw',
#     'summonerName': 'i v',
#     'summonerId': 'oXxSC8yPh5kIqCGTxaS41aS0I_U07zwaeYujOagufqjkGL4',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'V7_mBDpQkmRq_UxzOaBXs4OMa1-zrmvsVXDGex-eQOp4Dw',
#     'matchHistoryUri': '/v1/stats/player_history/NA/34463438',
#     'profileIcon': 23}},
#   {'participantId': 3,
#    'player': {'platformId': 'NA1',
#     'accountId': 'YWvJFu7eYUcQ2hAUFRSFMMVl5I7_ri4AUFOJ81lMAfBdDw',
#     'summonerName': 'Learn2Program',
#     'summonerId': 'BVi39_4VCMn3SgT9r65qJlVDbq8ix2tKPsIKeJpuV59L8N4',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'YWvJFu7eYUcQ2hAUFRSFMMVl5I7_ri4AUFOJ81lMAfBdDw',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/44502856',
#     'profileIcon': 1228}},
#   {'participantId': 4,
#    'player': {'platformId': 'NA',
#     'accountId': 'q5vQTcfqycaM16EI3h9nIRlshRkhuQuI3rDaHwg9dW3ocw',
#     'summonerName': 'BodyShapedDemon',
#     'summonerId': 'vOsN1R4MnxEwwHTFuuDfbUOV_U2SDemZRHACsrH3Q7pE5Mk',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'q5vQTcfqycaM16EI3h9nIRlshRkhuQuI3rDaHwg9dW3ocw',
#     'matchHistoryUri': '/v1/stats/player_history/NA/37159481',
#     'profileIcon': 26}},
#   {'participantId': 5,
#    'player': {'platformId': 'NA',
#     'accountId': 'PUgQNVaQQyhENgki7el-NsSLwKus96rX2CR1qO7kaggvAg',
#     'summonerName': 'prom11',
#     'summonerId': 'shfbgIHqdN4FATD__mBNyi48BB5Od3R8CB_LyX7OqJDmVtY',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'PUgQNVaQQyhENgki7el-NsSLwKus96rX2CR1qO7kaggvAg',
#     'matchHistoryUri': '/v1/stats/player_history/NA/41323900',
#     'profileIcon': 28}},
#   {'participantId': 6,
#    'player': {'platformId': 'NA',
#     'accountId': 'uiC0aZWO8_0-SjYujSq6wlkUCkw8JFLXXmZ9Wvd9XJKToA',
#     'summonerName': 'Young N Hung',
#     'summonerId': '89jplrgnKMTQBgURfjtsz1xRUsNuvEORqlwPr80R3HseTm0',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'uiC0aZWO8_0-SjYujSq6wlkUCkw8JFLXXmZ9Wvd9XJKToA',
#     'matchHistoryUri': '/v1/stats/player_history/NA/40476436',
#     'profileIcon': 4114}},
#   {'participantId': 7,
#    'player': {'platformId': 'NA',
#     'accountId': 'a9uf9G0HnHCEtQ1WB72P6ELJrRqIVB5EWKZsqtxx9d5wrw',
#     'summonerName': 'Han Solo',
#     'summonerId': 'zR4Zw40PJT_fzxzSZqUKSWQhshHQG1qpr0ssw1sah21oXZ0',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'a9uf9G0HnHCEtQ1WB72P6ELJrRqIVB5EWKZsqtxx9d5wrw',
#     'matchHistoryUri': '/v1/stats/player_history/NA/35818449',
#     'profileIcon': 4027}},
#   {'participantId': 8,
#    'player': {'platformId': 'NA1',
#     'accountId': 'miLSCMlXDkRobXOcBNb1MKPjQ8CQ0wzdWRtJy563tr-OvCs',
#     'summonerName': 'Sole  Memdry',
#     'summonerId': 'rp-ewp7Q-k8-2DGEFggKUNpKS_9sVkayGib8hAJR48Y0oyI',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'miLSCMlXDkRobXOcBNb1MKPjQ8CQ0wzdWRtJy563tr-OvCs',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/228965685',
#     'profileIcon': 4496}},
#   {'participantId': 9,
#    'player': {'platformId': 'NA1',
#     'accountId': '2uZZ0Eiu9ZlRoVx16HHhEVL0_dDmeXIy5lJUldwIzctXpQ',
#     'summonerName': 'prisoncore23',
#     'summonerId': 'S_0_GZ3fa_I0Pm_7Z_Crma4edVvIgqA_yDhexV6_qB9by4k',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': '2uZZ0Eiu9ZlRoVx16HHhEVL0_dDmeXIy5lJUldwIzctXpQ',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/47795939',
#     'profileIcon': 4448}},
#   {'participantId': 10,
#    'player': {'platformId': 'NA1',
#     'accountId': 'tm2CrZTm4VpyMli3Oi-82bA26vCJCQVCQgqnTiUIW1qQxJoqJwslNb44',
#     'summonerName': 'James11486',
#     'summonerId': 'xLO8Sn0NMeZoF2z1-XgOd7MzVeDizefwhSpGMBnIk7a_5Drr',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'tm2CrZTm4VpyMli3Oi-82bA26vCJCQVCQgqnTiUIW1qQxJoqJwslNb44',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/2077856577563200',
#     'profileIcon': 3788}}],
#  'participants': [{'participantId': 1,
#    'teamId': 100,
#    'championId': 145,
#    'spell1Id': 6,
#    'spell2Id': 7,
#    'stats': {'participantId': 1,
#     'win': False,
#     'item0': 3285,
#     'item1': 3089,
#     'item2': 3020,
#     'item3': 1042,
#     'item4': 1042,
#     'item5': 0,
#     'item6': 2052,
#     'kills': 3,
#     'deaths': 9,
#     'assists': 11,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'killingSprees': 0,
#     'longestTimeSpentLiving': 175,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 53071,
#     'magicDamageDealt': 23807,
#     'physicalDamageDealt': 29263,
#     'trueDamageDealt': 0,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 16843,
#     'magicDamageDealtToChampions': 12735,
#     'physicalDamageDealtToChampions': 4107,
#     'trueDamageDealtToChampions': 0,
#     'totalHeal': 3703,
#     'totalUnitsHealed': 4,
#     'damageSelfMitigated': 8128,
#     'damageDealtToObjectives': 133,
#     'damageDealtToTurrets': 133,
#     'visionScore': 0,
#     'timeCCingOthers': 0,
#     'totalDamageTaken': 16677,
#     'magicalDamageTaken': 9443,
#     'physicalDamageTaken': 6780,
#     'trueDamageTaken': 452,
#     'goldEarned': 9139,
#     'goldSpent': 8600,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 40,
#     'neutralMinionsKilled': 0,
#     'totalTimeCrowdControlDealt': 0,
#     'champLevel': 15,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8021,
#     'perk0Var1': 1229,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 9101,
#     'perk1Var1': 585,
#     'perk1Var2': 252,
#     'perk1Var3': 0,
#     'perk2': 9104,
#     'perk2Var1': 10,
#     'perk2Var2': 10,
#     'perk2Var3': 0,
#     'perk3': 8014,
#     'perk3Var1': 495,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8345,
#     'perk4Var1': 3,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8352,
#     'perk5Var1': 45,
#     'perk5Var2': 225,
#     'perk5Var3': 49,
#     'perkPrimaryStyle': 8000,
#     'perkSubStyle': 8300,
#     'statPerk0': 5005,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 1,
#     'creepsPerMinDeltas': {'0-10': 2.4000000000000004},
#     'xpPerMinDeltas': {'0-10': 731.9},
#     'goldPerMinDeltas': {'0-10': 438.3},
#     'csDiffPerMinDeltas': {'0-10': -0.19999999999999973},
#     'xpDiffPerMinDeltas': {'0-10': -55.799999999999955},
#     'damageTakenPerMinDeltas': {'0-10': 744.2},
#     'damageTakenDiffPerMinDeltas': {'0-10': -80.12000000000006},
#     'role': 'DUO_SUPPORT',
#     'lane': 'NONE'}},
#   {'participantId': 2,
#    'teamId': 100,
#    'championId': 11,
#    'spell1Id': 32,
#    'spell2Id': 4,
#    'stats': {'participantId': 2,
#     'win': False,
#     'item0': 3008,
#     'item1': 3508,
#     'item2': 3111,
#     'item3': 3024,
#     'item4': 3082,
#     'item5': 0,
#     'item6': 2052,
#     'kills': 4,
#     'deaths': 12,
#     'assists': 10,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'killingSprees': 0,
#     'longestTimeSpentLiving': 106,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 32616,
#     'magicDamageDealt': 0,
#     'physicalDamageDealt': 31374,
#     'trueDamageDealt': 1242,
#     'largestCriticalStrike': 455,
#     'totalDamageDealtToChampions': 11767,
#     'magicDamageDealtToChampions': 0,
#     'physicalDamageDealtToChampions': 10650,
#     'trueDamageDealtToChampions': 1117,
#     'totalHeal': 4779,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 19034,
#     'damageDealtToObjectives': 0,
#     'damageDealtToTurrets': 0,
#     'visionScore': 0,
#     'timeCCingOthers': 0,
#     'totalDamageTaken': 22224,
#     'magicalDamageTaken': 13535,
#     'physicalDamageTaken': 7835,
#     'trueDamageTaken': 853,
#     'goldEarned': 9281,
#     'goldSpent': 8750,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 26,
#     'neutralMinionsKilled': 0,
#     'totalTimeCrowdControlDealt': 22,
#     'champLevel': 15,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8128,
#     'perk0Var1': 566,
#     'perk0Var2': 14,
#     'perk0Var3': 0,
#     'perk1': 8126,
#     'perk1Var1': 152,
#     'perk1Var2': 0,
#     'perk1Var3': 0,
#     'perk2': 8138,
#     'perk2Var1': 18,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8135,
#     'perk3Var1': 513,
#     'perk3Var2': 5,
#     'perk3Var3': 0,
#     'perk4': 8304,
#     'perk4Var1': 6,
#     'perk4Var2': 3,
#     'perk4Var3': 0,
#     'perk5': 8347,
#     'perk5Var1': 0,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8100,
#     'perkSubStyle': 8300,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 2,
#     'creepsPerMinDeltas': {'0-10': 1.3},
#     'xpPerMinDeltas': {'0-10': 582.2},
#     'goldPerMinDeltas': {'0-10': 392.9},
#     'csDiffPerMinDeltas': {'0-10': -0.19999999999999973},
#     'xpDiffPerMinDeltas': {'0-10': -55.799999999999955},
#     'damageTakenPerMinDeltas': {'0-10': 936.2},
#     'damageTakenDiffPerMinDeltas': {'0-10': -80.12000000000006},
#     'role': 'DUO_SUPPORT',
#     'lane': 'NONE'}},
#   {'participantId': 3,
#    'teamId': 100,
#    'championId': 119,
#    'spell1Id': 4,
#    'spell2Id': 7,
#    'stats': {'participantId': 3,
#     'win': False,
#     'item0': 3043,
#     'item1': 3006,
#     'item2': 3035,
#     'item3': 1037,
#     'item4': 3147,
#     'item5': 0,
#     'item6': 2052,
#     'kills': 6,
#     'deaths': 8,
#     'assists': 9,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 2,
#     'killingSprees': 2,
#     'longestTimeSpentLiving': 195,
#     'doubleKills': 2,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 33348,
#     'magicDamageDealt': 0,
#     'physicalDamageDealt': 33348,
#     'trueDamageDealt': 0,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 16923,
#     'magicDamageDealtToChampions': 0,
#     'physicalDamageDealtToChampions': 16923,
#     'trueDamageDealtToChampions': 0,
#     'totalHeal': 2869,
#     'totalUnitsHealed': 3,
#     'damageSelfMitigated': 5989,
#     'damageDealtToObjectives': 0,
#     'damageDealtToTurrets': 0,
#     'visionScore': 0,
#     'timeCCingOthers': 13,
#     'totalDamageTaken': 16137,
#     'magicalDamageTaken': 9443,
#     'physicalDamageTaken': 6033,
#     'trueDamageTaken': 660,
#     'goldEarned': 9349,
#     'goldSpent': 8875,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 32,
#     'neutralMinionsKilled': 0,
#     'totalTimeCrowdControlDealt': 55,
#     'champLevel': 14,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 9923,
#     'perk0Var1': 49,
#     'perk0Var2': 71,
#     'perk0Var3': 0,
#     'perk1': 8139,
#     'perk1Var1': 937,
#     'perk1Var2': 0,
#     'perk1Var3': 0,
#     'perk2': 8138,
#     'perk2Var1': 18,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8135,
#     'perk3Var1': 423,
#     'perk3Var2': 5,
#     'perk3Var3': 0,
#     'perk4': 9103,
#     'perk4Var1': 0,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8014,
#     'perk5Var1': 371,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8100,
#     'perkSubStyle': 8000,
#     'statPerk0': 5005,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 3,
#     'creepsPerMinDeltas': {'0-10': 2.5},
#     'xpPerMinDeltas': {'0-10': 647.1},
#     'goldPerMinDeltas': {'0-10': 460},
#     'csDiffPerMinDeltas': {'0-10': -0.19999999999999973},
#     'xpDiffPerMinDeltas': {'0-10': -55.799999999999955},
#     'damageTakenPerMinDeltas': {'0-10': 573.5},
#     'damageTakenDiffPerMinDeltas': {'0-10': -80.12000000000006},
#     'role': 'DUO_SUPPORT',
#     'lane': 'NONE'}},
#   {'participantId': 4,
#    'teamId': 100,
#    'championId': 68,
#    'spell1Id': 32,
#    'spell2Id': 4,
#    'stats': {'participantId': 4,
#     'win': False,
#     'item0': 3151,
#     'item1': 0,
#     'item2': 3102,
#     'item3': 1026,
#     'item4': 3157,
#     'item5': 3020,
#     'item6': 2052,
#     'kills': 14,
#     'deaths': 12,
#     'assists': 15,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 3,
#     'killingSprees': 5,
#     'longestTimeSpentLiving': 117,
#     'doubleKills': 3,
#     'tripleKills': 2,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 77915,
#     'magicDamageDealt': 75036,
#     'physicalDamageDealt': 2179,
#     'trueDamageDealt': 698,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 39110,
#     'magicDamageDealtToChampions': 37449,
#     'physicalDamageDealtToChampions': 1121,
#     'trueDamageDealtToChampions': 538,
#     'totalHeal': 2504,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 20372,
#     'damageDealtToObjectives': 0,
#     'damageDealtToTurrets': 0,
#     'visionScore': 0,
#     'timeCCingOthers': 19,
#     'totalDamageTaken': 23511,
#     'magicalDamageTaken': 14112,
#     'physicalDamageTaken': 8779,
#     'trueDamageTaken': 618,
#     'goldEarned': 12118,
#     'goldSpent': 11650,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 46,
#     'neutralMinionsKilled': 0,
#     'totalTimeCrowdControlDealt': 166,
#     'champLevel': 16,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8010,
#     'perk0Var1': 1627,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 9111,
#     'perk1Var1': 747,
#     'perk1Var2': 290,
#     'perk1Var3': 0,
#     'perk2': 9105,
#     'perk2Var1': 7,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8014,
#     'perk3Var1': 1336,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8106,
#     'perk4Var1': 5,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8138,
#     'perk5Var1': 30,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8000,
#     'perkSubStyle': 8100,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 4,
#     'creepsPerMinDeltas': {'0-10': 1.2},
#     'xpPerMinDeltas': {'0-10': 685},
#     'goldPerMinDeltas': {'0-10': 602.3},
#     'csDiffPerMinDeltas': {'0-10': -0.19999999999999973},
#     'xpDiffPerMinDeltas': {'0-10': -55.799999999999955},
#     'damageTakenPerMinDeltas': {'0-10': 1070.2},
#     'damageTakenDiffPerMinDeltas': {'0-10': -80.12000000000006},
#     'role': 'DUO_SUPPORT',
#     'lane': 'NONE'}},
#   {'participantId': 5,
#    'teamId': 100,
#    'championId': 498,
#    'spell1Id': 32,
#    'spell2Id': 4,
#    'stats': {'participantId': 5,
#     'win': False,
#     'item0': 3184,
#     'item1': 3006,
#     'item2': 3046,
#     'item3': 3031,
#     'item4': 0,
#     'item5': 0,
#     'item6': 2052,
#     'kills': 2,
#     'deaths': 9,
#     'assists': 14,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'killingSprees': 0,
#     'longestTimeSpentLiving': 240,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 42095,
#     'magicDamageDealt': 0,
#     'physicalDamageDealt': 38708,
#     'trueDamageDealt': 3386,
#     'largestCriticalStrike': 314,
#     'totalDamageDealtToChampions': 14053,
#     'magicDamageDealtToChampions': 0,
#     'physicalDamageDealtToChampions': 13461,
#     'trueDamageDealtToChampions': 591,
#     'totalHeal': 1267,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 8458,
#     'damageDealtToObjectives': 1201,
#     'damageDealtToTurrets': 1201,
#     'visionScore': 0,
#     'timeCCingOthers': 16,
#     'totalDamageTaken': 19428,
#     'magicalDamageTaken': 11612,
#     'physicalDamageTaken': 6972,
#     'trueDamageTaken': 843,
#     'goldEarned': 8932,
#     'goldSpent': 8400,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 32,
#     'neutralMinionsKilled': 0,
#     'totalTimeCrowdControlDealt': 19,
#     'champLevel': 15,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8008,
#     'perk0Var1': 1,
#     'perk0Var2': 50,
#     'perk0Var3': 0,
#     'perk1': 9111,
#     'perk1Var1': 305,
#     'perk1Var2': 160,
#     'perk1Var3': 0,
#     'perk2': 9104,
#     'perk2Var1': 9,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8299,
#     'perk3Var1': 654,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8126,
#     'perk4Var1': 328,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8106,
#     'perk5Var1': 5,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8000,
#     'perkSubStyle': 8100,
#     'statPerk0': 5005,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 5,
#     'creepsPerMinDeltas': {'0-10': 1.9},
#     'xpPerMinDeltas': {'0-10': 730.7},
#     'goldPerMinDeltas': {'0-10': 476.9},
#     'csDiffPerMinDeltas': {'0-10': -0.19999999999999973},
#     'xpDiffPerMinDeltas': {'0-10': -55.799999999999955},
#     'damageTakenPerMinDeltas': {'0-10': 753.2},
#     'damageTakenDiffPerMinDeltas': {'0-10': -80.12000000000006},
#     'role': 'DUO_SUPPORT',
#     'lane': 'NONE'}},
#   {'participantId': 6,
#    'teamId': 200,
#    'championId': 14,
#    'spell1Id': 4,
#    'spell2Id': 32,
#    'stats': {'participantId': 6,
#     'win': True,
#     'item0': 2051,
#     'item1': 3111,
#     'item2': 3068,
#     'item3': 3065,
#     'item4': 3076,
#     'item5': 3082,
#     'item6': 2052,
#     'kills': 6,
#     'deaths': 6,
#     'assists': 20,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'killingSprees': 0,
#     'longestTimeSpentLiving': 207,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 51729,
#     'magicDamageDealt': 16559,
#     'physicalDamageDealt': 34985,
#     'trueDamageDealt': 184,
#     'largestCriticalStrike': 11,
#     'totalDamageDealtToChampions': 10485,
#     'magicDamageDealtToChampions': 3597,
#     'physicalDamageDealtToChampions': 6703,
#     'trueDamageDealtToChampions': 184,
#     'totalHeal': 2701,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 37246,
#     'damageDealtToObjectives': 2360,
#     'damageDealtToTurrets': 2360,
#     'visionScore': 0,
#     'timeCCingOthers': 22,
#     'totalDamageTaken': 30006,
#     'magicalDamageTaken': 13387,
#     'physicalDamageTaken': 15783,
#     'trueDamageTaken': 835,
#     'goldEarned': 10654,
#     'goldSpent': 9750,
#     'turretKills': 2,
#     'inhibitorKills': 1,
#     'totalMinionsKilled': 44,
#     'neutralMinionsKilled': 0,
#     'totalTimeCrowdControlDealt': 259,
#     'champLevel': 16,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': True,
#     'firstInhibitorKill': True,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8437,
#     'perk0Var1': 1192,
#     'perk0Var2': 961,
#     'perk0Var3': 0,
#     'perk1': 8446,
#     'perk1Var1': 1535,
#     'perk1Var2': 0,
#     'perk1Var3': 0,
#     'perk2': 8444,
#     'perk2Var1': 2370,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8451,
#     'perk3Var1': 254,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8224,
#     'perk4Var1': 798,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8237,
#     'perk5Var1': 333,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8400,
#     'perkSubStyle': 8200,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 6,
#     'creepsPerMinDeltas': {'0-10': 2.3},
#     'xpPerMinDeltas': {'0-10': 742.5},
#     'goldPerMinDeltas': {'0-10': 499.8},
#     'csDiffPerMinDeltas': {'0-10': 0.19999999999999973},
#     'xpDiffPerMinDeltas': {'0-10': 55.799999999999955},
#     'damageTakenPerMinDeltas': {'0-10': 1335.5},
#     'damageTakenDiffPerMinDeltas': {'0-10': 80.12000000000006},
#     'role': 'DUO_SUPPORT',
#     'lane': 'NONE'}},
#   {'participantId': 7,
#    'teamId': 200,
#    'championId': 59,
#    'spell1Id': 4,
#    'spell2Id': 32,
#    'stats': {'participantId': 7,
#     'win': True,
#     'item0': 3143,
#     'item1': 3047,
#     'item2': 3071,
#     'item3': 3053,
#     'item4': 3211,
#     'item5': 0,
#     'item6': 2052,
#     'kills': 14,
#     'deaths': 6,
#     'assists': 29,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 2,
#     'killingSprees': 6,
#     'longestTimeSpentLiving': 200,
#     'doubleKills': 2,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 31488,
#     'magicDamageDealt': 2793,
#     'physicalDamageDealt': 27744,
#     'trueDamageDealt': 950,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 19155,
#     'magicDamageDealtToChampions': 2233,
#     'physicalDamageDealtToChampions': 15971,
#     'trueDamageDealtToChampions': 950,
#     'totalHeal': 3732,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 27942,
#     'damageDealtToObjectives': 1512,
#     'damageDealtToTurrets': 1512,
#     'visionScore': 0,
#     'timeCCingOthers': 29,
#     'totalDamageTaken': 21665,
#     'magicalDamageTaken': 10475,
#     'physicalDamageTaken': 10833,
#     'trueDamageTaken': 356,
#     'goldEarned': 12375,
#     'goldSpent': 11250,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 23,
#     'neutralMinionsKilled': 0,
#     'totalTimeCrowdControlDealt': 262,
#     'champLevel': 17,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'firstBloodKill': True,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': True,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': True,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8112,
#     'perk0Var1': 1945,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 8139,
#     'perk1Var1': 1001,
#     'perk1Var2': 0,
#     'perk1Var3': 0,
#     'perk2': 8138,
#     'perk2Var1': 18,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8135,
#     'perk3Var1': 1037,
#     'perk3Var2': 5,
#     'perk3Var3': 0,
#     'perk4': 8304,
#     'perk4Var1': 4,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8345,
#     'perk5Var1': 3,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8100,
#     'perkSubStyle': 8300,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 7,
#     'creepsPerMinDeltas': {'0-10': 1.6},
#     'xpPerMinDeltas': {'0-10': 828.5999999999999},
#     'goldPerMinDeltas': {'0-10': 672.6},
#     'csDiffPerMinDeltas': {'0-10': 0.19999999999999973},
#     'xpDiffPerMinDeltas': {'0-10': 55.799999999999955},
#     'damageTakenPerMinDeltas': {'0-10': 1012.3},
#     'damageTakenDiffPerMinDeltas': {'0-10': 80.12000000000006},
#     'role': 'DUO_SUPPORT',
#     'lane': 'NONE'}},
#   {'participantId': 8,
#    'teamId': 200,
#    'championId': 17,
#    'spell1Id': 4,
#    'spell2Id': 7,
#    'stats': {'participantId': 8,
#     'win': True,
#     'item0': 3285,
#     'item1': 3020,
#     'item2': 3115,
#     'item3': 3136,
#     'item4': 0,
#     'item5': 0,
#     'item6': 2052,
#     'kills': 9,
#     'deaths': 8,
#     'assists': 24,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'killingSprees': 2,
#     'longestTimeSpentLiving': 204,
#     'doubleKills': 2,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 42069,
#     'magicDamageDealt': 35569,
#     'physicalDamageDealt': 5323,
#     'trueDamageDealt': 1176,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 24653,
#     'magicDamageDealtToChampions': 21764,
#     'physicalDamageDealtToChampions': 1713,
#     'trueDamageDealtToChampions': 1176,
#     'totalHeal': 4197,
#     'totalUnitsHealed': 3,
#     'damageSelfMitigated': 5643,
#     'damageDealtToObjectives': 889,
#     'damageDealtToTurrets': 889,
#     'visionScore': 0,
#     'timeCCingOthers': 39,
#     'totalDamageTaken': 16526,
#     'magicalDamageTaken': 10285,
#     'physicalDamageTaken': 6169,
#     'trueDamageTaken': 70,
#     'goldEarned': 10955,
#     'goldSpent': 8900,
#     'turretKills': 1,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 29,
#     'neutralMinionsKilled': 0,
#     'totalTimeCrowdControlDealt': 226,
#     'champLevel': 17,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': True,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': True,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8214,
#     'perk0Var1': 1615,
#     'perk0Var2': 59,
#     'perk0Var3': 0,
#     'perk1': 8226,
#     'perk1Var1': 250,
#     'perk1Var2': 377,
#     'perk1Var3': 0,
#     'perk2': 8233,
#     'perk2Var1': 7,
#     'perk2Var2': 40,
#     'perk2Var3': 0,
#     'perk3': 8237,
#     'perk3Var1': 511,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8126,
#     'perk4Var1': 1362,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8135,
#     'perk5Var1': 2612,
#     'perk5Var2': 5,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8200,
#     'perkSubStyle': 8100,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 8,
#     'creepsPerMinDeltas': {'0-10': 1.8},
#     'xpPerMinDeltas': {'0-10': 654.2},
#     'goldPerMinDeltas': {'0-10': 468.6},
#     'csDiffPerMinDeltas': {'0-10': 0.19999999999999973},
#     'xpDiffPerMinDeltas': {'0-10': 55.799999999999955},
#     'damageTakenPerMinDeltas': {'0-10': 750.0999999999999},
#     'damageTakenDiffPerMinDeltas': {'0-10': 80.12000000000006},
#     'role': 'DUO_SUPPORT',
#     'lane': 'NONE'}},
#   {'participantId': 9,
#    'teamId': 200,
#    'championId': 82,
#    'spell1Id': 32,
#    'spell2Id': 4,
#    'stats': {'participantId': 9,
#     'win': True,
#     'item0': 3116,
#     'item1': 1052,
#     'item2': 2031,
#     'item3': 3065,
#     'item4': 1029,
#     'item5': 3151,
#     'item6': 2052,
#     'kills': 7,
#     'deaths': 4,
#     'assists': 20,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 2,
#     'killingSprees': 2,
#     'longestTimeSpentLiving': 314,
#     'doubleKills': 1,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 47392,
#     'magicDamageDealt': 41005,
#     'physicalDamageDealt': 5686,
#     'trueDamageDealt': 700,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 18418,
#     'magicDamageDealtToChampions': 15613,
#     'physicalDamageDealtToChampions': 2180,
#     'trueDamageDealtToChampions': 625,
#     'totalHeal': 9547,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 15830,
#     'damageDealtToObjectives': 967,
#     'damageDealtToTurrets': 967,
#     'visionScore': 0,
#     'timeCCingOthers': 12,
#     'totalDamageTaken': 20792,
#     'magicalDamageTaken': 8360,
#     'physicalDamageTaken': 12175,
#     'trueDamageTaken': 257,
#     'goldEarned': 10649,
#     'goldSpent': 9385,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 45,
#     'neutralMinionsKilled': 0,
#     'totalTimeCrowdControlDealt': 146,
#     'champLevel': 17,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': True,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8010,
#     'perk0Var1': 973,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 9111,
#     'perk1Var1': 1082,
#     'perk1Var2': 270,
#     'perk1Var3': 0,
#     'perk2': 9104,
#     'perk2Var1': 7,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8299,
#     'perk3Var1': 730,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8139,
#     'perk4Var1': 982,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8135,
#     'perk5Var1': 2806,
#     'perk5Var2': 5,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8000,
#     'perkSubStyle': 8100,
#     'statPerk0': 5005,
#     'statPerk1': 5008,
#     'statPerk2': 5003},
#    'timeline': {'participantId': 9,
#     'creepsPerMinDeltas': {'0-10': 2.5},
#     'xpPerMinDeltas': {'0-10': 726.5},
#     'goldPerMinDeltas': {'0-10': 490},
#     'csDiffPerMinDeltas': {'0-10': 0.19999999999999973},
#     'xpDiffPerMinDeltas': {'0-10': 55.799999999999955},
#     'damageTakenPerMinDeltas': {'0-10': 717.9},
#     'damageTakenDiffPerMinDeltas': {'0-10': 80.12000000000006},
#     'role': 'DUO_SUPPORT',
#     'lane': 'NONE'}},
#   {'participantId': 10,
#    'teamId': 200,
#    'championId': 1,
#    'spell1Id': 4,
#    'spell2Id': 14,
#    'stats': {'participantId': 10,
#     'win': True,
#     'item0': 3029,
#     'item1': 3285,
#     'item2': 3020,
#     'item3': 1058,
#     'item4': 1058,
#     'item5': 0,
#     'item6': 2052,
#     'kills': 14,
#     'deaths': 6,
#     'assists': 18,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'killingSprees': 5,
#     'longestTimeSpentLiving': 205,
#     'doubleKills': 2,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 47917,
#     'magicDamageDealt': 40247,
#     'physicalDamageDealt': 2685,
#     'trueDamageDealt': 4984,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 16133,
#     'magicDamageDealtToChampions': 14938,
#     'physicalDamageDealtToChampions': 700,
#     'trueDamageDealtToChampions': 494,
#     'totalHeal': 3799,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 6164,
#     'damageDealtToObjectives': 2000,
#     'damageDealtToTurrets': 2000,
#     'visionScore': 0,
#     'timeCCingOthers': 21,
#     'totalDamageTaken': 16198,
#     'magicalDamageTaken': 7675,
#     'physicalDamageTaken': 7795,
#     'trueDamageTaken': 727,
#     'goldEarned': 11820,
#     'goldSpent': 9750,
#     'turretKills': 1,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 39,
#     'neutralMinionsKilled': 0,
#     'totalTimeCrowdControlDealt': 61,
#     'champLevel': 16,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': True,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': True,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8128,
#     'perk0Var1': 1260,
#     'perk0Var2': 23,
#     'perk0Var3': 0,
#     'perk1': 8139,
#     'perk1Var1': 892,
#     'perk1Var2': 0,
#     'perk1Var3': 0,
#     'perk2': 8138,
#     'perk2Var1': 30,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8135,
#     'perk3Var1': 1436,
#     'perk3Var2': 5,
#     'perk3Var3': 0,
#     'perk4': 8237,
#     'perk4Var1': 273,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8275,
#     'perk5Var1': 9,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8100,
#     'perkSubStyle': 8200,
#     'statPerk0': 5007,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 10,
#     'creepsPerMinDeltas': {'0-10': 2.1},
#     'xpPerMinDeltas': {'0-10': 704.1},
#     'goldPerMinDeltas': {'0-10': 502.29999999999995},
#     'csDiffPerMinDeltas': {'0-10': 0.19999999999999973},
#     'xpDiffPerMinDeltas': {'0-10': 55.799999999999955},
#     'damageTakenPerMinDeltas': {'0-10': 662.1},
#     'damageTakenDiffPerMinDeltas': {'0-10': 80.12000000000006},
#     'role': 'DUO_SUPPORT',
#     'lane': 'NONE'}}],
#  'teams': [{'teamId': 100,
#    'win': 'Fail',
#    'firstBlood': False,
#    'firstTower': False,
#    'firstInhibitor': False,
#    'firstBaron': False,
#    'firstDragon': False,
#    'firstRiftHerald': False,
#    'towerKills': 0,
#    'inhibitorKills': 0,
#    'baronKills': 0,
#    'dragonKills': 0,
#    'vilemawKills': 0,
#    'riftHeraldKills': 0,
#    'dominionVictoryScore': 0,
#    'bans': []},
#   {'teamId': 200,
#    'win': 'Win',
#    'firstBlood': True,
#    'firstTower': True,
#    'firstInhibitor': True,
#    'firstBaron': False,
#    'firstDragon': False,
#    'firstRiftHerald': False,
#    'towerKills': 4,
#    'inhibitorKills': 1,
#    'baronKills': 0,
#    'dragonKills': 0,
#    'vilemawKills': 0,
#    'riftHeraldKills': 0,
#    'dominionVictoryScore': 0,
#    'bans': []}]}

# %%
# ParticipantAccountInfo Array!
#gets ID : Summoner Name For Each Game!
Object_Of_Id_SummonerNames2 = {}
#list = []
for i in range(0,10):
    currGame_ParticipantId = AllGames[i]['participantAccountInfo'][i]['participantId']
    currGame_SummonerName = AllGames[i]['participantAccountInfo'][i]['player']['summonerName']
    Object_Of_Id_SummonerNames2.update({currGame_ParticipantId : currGame_SummonerName})

#list.append(Object_Of_Id_SummonerNames2)
Object_Of_Id_SummonerNames2    
#currGame_ParticipantId, currGame_SummonerName
#for x in list:
    #print(x)
# Out:
# {1: 'IQARUS',
#  2: 'i v',
#  3: 'Learn2Program',
#  4: 'BodyShapedDemon',
#  5: 'prom11',
#  6: 'Young N Hung',
#  7: 'Han Solo',
#  8: 'Sole  Memdry',
#  9: 'prisoncore23',
#  10: 'James11486'}

# %%
# Participants Array!
champion = AllGames[0]['participants'][0]['championId']
participantId = AllGames[0]['participants'][0]['participantId']
spell1 = AllGames[0]['participants'][0]['spell1Id']
spell2 = AllGames[0]['participants'][0]['spell2Id']
teamId = AllGames[0]['participants'][0]['teamId']
#stats object specifics
kills = AllGames[0]['participants'][0]['stats']['kills']
deaths = AllGames[0]['participants'][0]['stats']['deaths']
assists = AllGames[0]['participants'][0]['stats']['assists']
totalDamageDealtToChampions = AllGames[0]['participants'][0]['stats']['totalDamageDealtToChampions']
wardsPlaced = AllGames[0]['participants'][0]['stats']['wardsPlaced']
largestMultiKill = AllGames[0]['participants'][0]['stats']['largestMultiKill']
# Items
item0 = AllGames[0]['participants'][0]['stats']['item0']
item1 = AllGames[0]['participants'][0]['stats']['item1']
item2 = AllGames[0]['participants'][0]['stats']['item2']
item3 = AllGames[0]['participants'][0]['stats']['item3']
item4 = AllGames[0]['participants'][0]['stats']['item4']
item5 = AllGames[0]['participants'][0]['stats']['item5']
item6 = AllGames[0]['participants'][0]['stats']['item6']
#Bool for win = true
win = AllGames[0]['participants'][0]['stats']['win']
#timeline details
timeline = AllGames[0]['participants'][0]['timeline'] #Readability!
creepPerMin_Pre10Mins = timeline['creepsPerMinDeltas']['0-10']
creepPerMin_Post10Mins = timeline['creepsPerMinDeltas']['10-20']
csDiffPerMin_Pre10Mins = timeline['csDiffPerMinDeltas']['0-10']
csDiffPerMin_Post10Mins = timeline['csDiffPerMinDeltas']['10-20']
# role + Lane
lane = timeline['lane']
role = timeline['role']

#champion, stats, n more...
champion, participantId, spell1, spell2, teamId, kills, deaths, assists, totalDamageDealtToChampions, wardsPlaced, win, lane, role
# Out:
# (104, 1, 4, 11, 100, 7, 6, 17, 20397, 1, True)

# %%
# CS Details
creepPerMin_Pre10Mins, creepPerMin_Post10Mins, csDiffPerMin_Pre10Mins, csDiffPerMin_Post10Mins
# Out:
# (0.2, 0.6, 0.2, 0)

# %%
# Items
item0, item1, item2, item3, item4, item5, item6
# Out:
# (1412, 3095, 3111, 3812, 3036, 0, 3364)

# %%
# Teams Array!
# Careful when writing this, its per-team stats
baronKills = AllGames[0]['teams'][0]['baronKills']
dragonKills = AllGames[0]['teams'][0]['dragonKills']
riftHeraldKills = AllGames[0]['teams'][0]['riftHeraldKills']
towerKills = AllGames[0]['teams'][0]['towerKills']
teamId = AllGames[0]['teams'][0]['teamId']
win = AllGames[0]['teams'][0]['win']

bothTeams = 2
bannedList = []
team100StatList = []
team200StatList = []
Object_Update = {}
for teamIndex in range(0,bothTeams):
    for banIndex in range(0,5):
        bannedList.append(AllGames[0]['teams'][teamIndex]['bans'][banIndex]['championId'])
    baronKills = AllGames[0]['teams'][teamIndex]['baronKills']
    dragonKills = AllGames[0]['teams'][teamIndex]['dragonKills']
    riftHeraldKills = AllGames[0]['teams'][teamIndex]['riftHeraldKills']
    towerKills = AllGames[0]['teams'][teamIndex]['towerKills']
    teamId = AllGames[0]['teams'][teamIndex]['teamId']
    win = AllGames[0]['teams'][teamIndex]['win']
    if teamIndex == 0:
        Object_Update.update({100:{baronKills, dragonKills,riftHeraldKills,towerKills,teamId,win}})
        team100StatList.append(Object_Update)
    if teamIndex == 1:
        Object_Update.update({200:{baronKills, dragonKills,riftHeraldKills,towerKills,teamId,win}})
        team200StatList.append(Object_Update)
    

#bannedList, baronKills, dragonKills, riftHeraldKills, towerKills, teamId, win
team100StatList, team200StatList, bannedList
# Out:
# ([{100: {10, 100, 2, 4, 'Win'}, 200: {0, 1, 2, 200, 'Fail'}},
#   {100: {10, 100, 2, 4, 'Win'}, 200: {0, 1, 2, 200, 'Fail'}}],
#  [11, 51, 89, 131, 75, 157, 523, 555, 350, 420])
